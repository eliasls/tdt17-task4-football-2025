# %% [markdown]
# ## Prepare data

# %%
import os, sys
import importlib

PROJECT_ROOT = "/cluster/work/eliasls/tdt17/task4"
if PROJECT_ROOT not in sys.path:
  sys.path.append(PROJECT_ROOT)

import shutil
from pathlib import Path
from utils import exploratory_data_analysis, prepare_data
from PIL import Image

# %%
DATA_ROOT = "/cluster/projects/vc/courses/TDT17/other/Football2025"
root_dir = os.path.join(DATA_ROOT, "")
matches = sorted(os.listdir(root_dir))
paths = exploratory_data_analysis.generate_paths(root_dir, matches)
paths
# Out:
# {'RBK-AALESUND': {'images': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-AALESUND/data/images/train',
#   'labels': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-AALESUND/labels/train',
#   'annotations': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-AALESUND/annotations.xml',
#   'data_yaml': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-AALESUND/data.yaml'},
#  'RBK-BODO-PART1': {'images': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part1/RBK_BODO_PART1/data/images/train',
#   'labels': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part1/RBK_BODO_PART1/labels/train',
#   'annotations': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part1/RBK_BODO_PART1/annotations.xml',
#   'data_yaml': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part1/RBK_BODO_PART1/data.yaml'},
#  'RBK-BODO-PART2': {'images': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part2/RBK_BODO_PART2/data/images/train',
#   'labels': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part2/RBK_BODO_PART2/labels/train',
#   'annotations': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part2/RBK_BODO_PART2/annotations.xml',
#   'data_yaml': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part2/RBK_BODO_PART2/data.yaml'},
#  'RBK-BODO-PART3': {'images': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part3/RBK_BODO_PART3/data/images/train',
#   'labels': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part3/RBK_BODO_PART3/labels/train',
#   'annotations': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part3/RBK_BODO_PART3/annotations.xml',
#   'data_yaml': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part3/RBK_BODO_PART3/data.yaml'},
#  'RBK-FREDRIKSTAD': {'images': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-FREDRIKSTAD/data/images/train',
#   'labels': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-FREDRIKSTAD/labels/train',
#   'annotations': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-FREDRIKSTAD/annotations.xml',
#   'data_yaml': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-FREDRIKSTAD/data.yaml'},
#  'RBK-HamKam': {'images': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-HamKam/data/images/train',
#   'labels': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-HamKam/labels/train',
#   'annotations': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-HamKam/annotations.xml',
#   'data_yaml': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-HamKam/data.yaml'},
#  'RBK-VIKING': {'images': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-VIKING/data/images/train',
#   'labels': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-VIKING/labels/train',
#   'annotations': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-VIKING/annotations.xml',
#   'data_yaml': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-VIKING/data.yaml'}}

# %%
importlib.reload(prepare_data)

src_path = paths["RBK-BODO-PART1"]["images"] + "/frame_000003.png"
dst_path = "/cluster/work/eliasls/tdt17/task4/data-mask-r-cnn/images/train/"
prepare_data.copy_file(src_path, dst_path)

# %%
matches = list(paths.keys())
matches

train = ['RBK-BODO-PART1','RBK-BODO-PART2','RBK-BODO-PART3', 'RBK-HamKam','RBK-VIKING']
test = ["RBK-AALESUND"]
val = ["RBK-FREDRIKSTAD"]

base_dst = Path("/cluster/work/eliasls/tdt17/task4/data-mask-r-cnn/images/train")
for match in train:
  src_dir = Path(paths[match]["images"])
  dst_dir = base_dst / match
  dst_dir.mkdir(parents=True, exist_ok=True)

  for image_name in sorted(os.listdir(src_dir)):
    src_path = src_dir / image_name
    dst_path = dst_dir / image_name
    prepare_data.copy_file(src_path, dst_path)

# %%
base_dst = Path("/cluster/work/eliasls/tdt17/task4/data-mask-r-cnn/images/val")    
for match in val:
  src_dir = Path(paths[match]["images"])
  dst_dir = base_dst / match
  dst_dir.mkdir(parents=True, exist_ok=True)

  for image_name in sorted(os.listdir(src_dir)):
    src_path = src_dir / image_name
    dst_path = dst_dir / image_name
    prepare_data.copy_file(src_path, dst_path)

# %%
base_dst = Path("/cluster/work/eliasls/tdt17/task4/data-mask-r-cnn/images/test")    
for match in test:
  src_dir = Path(paths[match]["images"])
  dst_dir = base_dst / match
  dst_dir.mkdir(parents=True, exist_ok=True)

  for image_name in sorted(os.listdir(src_dir)):
    src_path = src_dir / image_name
    dst_path = dst_dir / image_name
    prepare_data.copy_file(src_path, dst_path)

# %%
importlib.reload(prepare_data)
image_root = Path("/cluster/work/eliasls/tdt17/task4/data-mask-r-cnn/images")
annotations_out = Path("/cluster/work/eliasls/tdt17/task4/data-mask-r-cnn/annotations")

#prepare_data.build_split("train", train, paths, image_root, annotations_out / "train.json")
prepare_data.build_split("val", val, paths, image_root, annotations_out / "val.json")
prepare_data.build_split("test", test, paths, image_root, annotations_out / "test.json")
# Out:
# Saved /cluster/work/eliasls/tdt17/task4/data-mask-r-cnn/annotations/val.json with 1816 images, 42767 boxes
# Saved /cluster/work/eliasls/tdt17/task4/data-mask-r-cnn/annotations/test.json with 1802 images, 42169 boxes
