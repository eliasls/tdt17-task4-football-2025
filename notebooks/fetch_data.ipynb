# %%
import os, sys
import shutil
from pathlib import Path
PROJECT_ROOT = "/cluster/work/eliasls/tdt17/task4"
if PROJECT_ROOT not in sys.path:
  sys.path.append(PROJECT_ROOT)
from utils import exploratory_data_analysis, fetch_data
import importlib
importlib.reload(fetch_data)

# %%
print(os.getcwd())
print(Path.cwd())

# %%
importlib.reload(fetch_data)
move_dict = {
  'RBK-AALESUND': 
    {
      'src_images': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-AALESUND/data/images/train',
      'src_labels': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-AALESUND/labels/train',
      "dst_images": "/cluster/work/eliasls/tdt17/task4/datasets/images/test",
      "dst_labels": "/cluster/work/eliasls/tdt17/task4/datasets/labels/test",
      "file_name" : "RBK_AALESUND_frame_"
    },
    
 'RBK-BODO-PART1': 
    {
      'src_images': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part1/RBK_BODO_PART1/data/images/train',
      'src_labels': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part1/RBK_BODO_PART1/labels/train',
      "dst_images": "/cluster/work/eliasls/tdt17/task4/datasets/images/train",
      "dst_labels": "/cluster/work/eliasls/tdt17/task4/datasets/labels/train", 
      "file_name" : "RBK_BODO_PART1_frame_"
    },
    
 'RBK-BODO-PART2': 
    {
      'src_images': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part2/RBK_BODO_PART2/data/images/train',
      'src_labels': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part2/RBK_BODO_PART2/labels/train',
      "dst_images": "/cluster/work/eliasls/tdt17/task4/datasets/images/train",
      "dst_labels": "/cluster/work/eliasls/tdt17/task4/datasets/labels/train",
      "file_name" : "RBK_BODO_PART2_frame_"
   },
  
 'RBK-BODO-PART3': 
    {
      'src_images': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part3/RBK_BODO_PART3/data/images/train',
      'src_labels': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part3/RBK_BODO_PART3/labels/train',
      "dst_images": "/cluster/work/eliasls/tdt17/task4/datasets/images/train",
      "dst_labels": "/cluster/work/eliasls/tdt17/task4/datasets/labels/train",
      "file_name" : "RBK_BODO_PART3_frame_"
    },
    
 'RBK-FREDRIKSTAD':
    {
      'src_images': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-FREDRIKSTAD/data/images/train',
      'src_labels': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-FREDRIKSTAD/labels/train',
      "dst_images": "/cluster/work/eliasls/tdt17/task4/datasets/images/train",
      "dst_labels": "/cluster/work/eliasls/tdt17/task4/datasets/labels/train",
      "file_name" : "RBK_FREDRIKSTAD_frame_"
    },
  
 'RBK-HamKam': 
    {
      'src_images': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-HamKam/data/images/train',
      'src_labels': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-HamKam/labels/train',
      "dst_images": "/cluster/work/eliasls/tdt17/task4/datasets/images/val",
      "dst_labels": "/cluster/work/eliasls/tdt17/task4/datasets/labels/val",
      "file_name" : "RBK_HamKam_frame_"
      
    },
 
 'RBK-VIKING':
    {
      'src_images': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-VIKING/data/images/train',
      'src_labels': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-VIKING/labels/train',
      "dst_images": "/cluster/work/eliasls/tdt17/task4/datasets/images/train",
      "dst_labels": "/cluster/work/eliasls/tdt17/task4/datasets/labels/train",
      "file_name" : "RBK_VIKING_frame_"
    }
  }

# %%
""" importlib.reload(fetch_data)
fetch_data.get_data(move_dict) """

# %%
DATA_ROOT = "/cluster/projects/vc/courses/TDT17/other/Football2025"
root_dir = os.path.join(DATA_ROOT, "")

paths = exploratory_data_analysis.generate_paths(root_dir, matches)
match_images = {}

for key in paths.keys():
  images_path = paths[key]["images"]
  #print(f"Path: {images_path}")
  match_images[key] = sorted(os.listdir(images_path))

# %%
for key in move_dict.keys():
  missing_labels = exploratory_data_analysis.get_missing_labels(sorted(os.listdir(move_dict[key]["dst_images"])), move_dict[key]["dst_labels"])
  print(f"{key} missing labels: {missing_labels}")

# %% [markdown]
# #### Remove class = 2 in data.yaml

# %%
#matches with class = 2: RBK-AALESUND, RBK-BODO-PART3, RBK-FREDRIKSTAD	
importlib.reload(fetch_data)
total = 0
for match in move_dict.keys():
  print(match)
  files = sorted(os.listdir(move_dict[match]["dst_labels"]))
  path = Path(move_dict[match]["dst_labels"])
  count = 0
  for file in files:
    path_file = path / file
    has_class = fetch_data.has_class(path_file, 2)
    if has_class > 0:
      count += has_class
  print(count)
  total += count
print(total)

# %%
move_dict = {
  
  'RBK-AALESUND': 
    {
      'src_images': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-AALESUND/data/images/train',
      'src_labels': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-AALESUND/labels/train',
      "dst_images": "/cluster/work/eliasls/tdt17/task4/datasets/images/test",
      "dst_labels": "/cluster/work/eliasls/tdt17/task4/datasets/labels/test",
      "file_name" : "RBK_AALESUND_frame_"
    },
    
 'RBK-BODO-PART1': 
    {
      'src_images': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part1/RBK_BODO_PART1/data/images/train',
      'src_labels': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-BODO/part1/RBK_BODO_PART1/labels/train',
      "dst_images": "/cluster/work/eliasls/tdt17/task4/datasets/images/train",
      "dst_labels": "/cluster/work/eliasls/tdt17/task4/datasets/labels/train", 
      "file_name" : "RBK_BODO_PART1_frame_"
    },
    
  'RBK-HamKam': 
    {
      'src_images': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-HamKam/data/images/train',
      'src_labels': '/cluster/projects/vc/courses/TDT17/other/Football2025/RBK-HamKam/labels/train',
      "dst_images": "/cluster/work/eliasls/tdt17/task4/datasets/images/val",
      "dst_labels": "/cluster/work/eliasls/tdt17/task4/datasets/labels/val",
      "file_name" : "RBK_HamKam_frame_"
      
    }
  
  
}

# %%
#matches with class = 2: RBK-AALESUND, RBK-BODO-PART3, RBK-FREDRIKSTAD	
importlib.reload(fetch_data)
total = 0
for match in move_dict.keys():
  print(match)
  files = sorted(os.listdir(move_dict[match]["dst_labels"]))
  path = Path(move_dict[match]["dst_labels"])
  count = 0
  for file in files:
    path_file = path / file
    has_class = fetch_data.has_class(path_file, 2)
    if has_class > 0:
      count += has_class
  print(count)
  total += count
print(total)

# %%
importlib.reload(fetch_data)
label_path_test = "/cluster/work/eliasls/tdt17/task4/datasets/labels/test"
label_path_train = "/cluster/work/eliasls/tdt17/task4/datasets/labels/train"
label_path_val = "/cluster/work/eliasls/tdt17/task4/datasets/labels/val"
fetch_data.remove_class_from_labels(Path(label_path_test), class_id=2)
fetch_data.remove_class_from_labels(Path(label_path_train), class_id=2)
fetch_data.remove_class_from_labels(Path(label_path_val), class_id=2)

# %%
importlib.reload(fetch_data)
total = 0
for match in move_dict.keys():
  print(match)
  files = sorted(os.listdir(move_dict[match]["dst_labels"]))
  path = Path(move_dict[match]["dst_labels"])
  count = 0
  for file in files:
    path_file = path / file
    has_class = fetch_data.has_class(path_file, 2)
    if has_class > 0:
      count += has_class
  print(count)
  total += count
print(total)

# %%
a =  sorted(os.listdir(label_path_train))
print(len(a))
b = sorted(os.listdir(label_path_val))
print(len(b))
